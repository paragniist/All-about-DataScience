# %% [markdown]
# ### Sample Space :

# %% [markdown]
# ![alt text](1.png)

# %% [markdown]
# ![alt text](<Screenshot 2025-11-06 at 6.46.59 PM.png>)

# %% [markdown]
# ![alt text](<Screenshot 2025-11-06 at 6.47.13 PM.png>)

# %% [markdown]
# ![alt text](<Screenshot 2025-11-06 at 6.46.47 PM.png>)
