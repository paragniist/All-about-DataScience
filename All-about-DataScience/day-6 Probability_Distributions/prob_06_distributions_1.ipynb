# %%
import numpy as np
import pandas as pd
import math

from scipy.stats import binom

# %%
pd.value_counts(np.random.choice(["H", "T"], size=1000), normalize=True)
# Out:
# /var/folders/j_/njpl090n1z9832p7my5n1s0c0000gn/T/ipykernel_5156/3778926233.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(np.random.choice(["H", "T"], size=1000), normalize=True)
# /var/folders/j_/njpl090n1z9832p7my5n1s0c0000gn/T/ipykernel_5156/3778926233.py:1: FutureWarning: The behavior of value_counts with object-dtype is deprecated. In a future version, this will *not* perform dtype inference on the resulting index. To retain the old behavior, use `result.index = result.index.infer_objects()`
#   pd.value_counts(np.random.choice(["H", "T"], size=1000), normalize=True)
# H    0.528
# T    0.472
# Name: proportion, dtype: float64

# %% [markdown]
# A bag has 3 red and 2 blue balls.
#
#
# You pick a ball, write its colour, and put it back in the bag.
#
# This is done 4 times in total.
#
# If all 4 times, the red ball was drawn, you win Rs 150, otherwise you lose Rs 10.
#
# Would you play this game?

# %%
rolls = np.random.choice(["R", "R", "R", "B", "B"], size=4)
rolls
# Out:
# array(['B', 'B', 'R', 'B'], dtype='<U1')

# %%
np.count_nonzero(rolls=="R")
pd.value_counts(rolls)
# Out:
# /var/folders/j_/njpl090n1z9832p7my5n1s0c0000gn/T/ipykernel_5156/2812230813.py:2: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(rolls)
# /var/folders/j_/njpl090n1z9832p7my5n1s0c0000gn/T/ipykernel_5156/2812230813.py:2: FutureWarning: The behavior of value_counts with object-dtype is deprecated. In a future version, this will *not* perform dtype inference on the resulting index. To retain the old behavior, use `result.index = result.index.infer_objects()`
#   pd.value_counts(rolls)
# B    3
# R    1
# Name: count, dtype: int64

# %%
red_values = []

for person in range(10000):
    rolls = np.random.choice(["R", "R", "R", "B", "B"], size=4)
    num_reds = np.count_nonzero(rolls=="R")
    red_values.append(num_reds)

print(rolls)
pd.value_counts(red_values, normalize=True)
# Out:
# ['B' 'R' 'R' 'B']
# /var/folders/j_/njpl090n1z9832p7my5n1s0c0000gn/T/ipykernel_5156/1404449106.py:9: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(red_values, normalize=True)
# /var/folders/j_/njpl090n1z9832p7my5n1s0c0000gn/T/ipykernel_5156/1404449106.py:9: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pd.value_counts(red_values, normalize=True)
# 2    0.3460
# 3    0.3435
# 1    0.1523
# 4    0.1327
# 0    0.0255
# Name: proportion, dtype: float64

# %%
np.mean(red_values)
# Out:
# np.float64(2.4035)

# %% [markdown]
# ## Rule-based probability

# %% [markdown]
# PMF: Probability Mass Function

# %%
math.comb(4, 0) # 4C0
# Out:
# 1

# %%
math.comb(4, 0) * (3/5)**0 * (2/5)**4
# Out:
# 0.025600000000000005

# %%
binom.pmf(n=4, p=3/5, k=0)
# Out:
# np.float64(0.025599999999999984)

# %%
math.comb(4, 1) * (3/5)**1 * (2/5)**3
# Out:
# 0.15360000000000004

# %%
binom.pmf(n=4, p=3/5, k=1)
# Out:
# np.float64(0.15359999999999993)

# %%
math.comb(4, 2) * (3/5)**2 * (2/5)**2
# Out:
# 0.3456000000000001

# %%
binom.pmf(n=4, p=3/5, k=2)
# Out:
# np.float64(0.34560000000000024)

# %%
math.comb(4, 3) * (3/5)**3 * (2/5)**1
# Out:
# 0.34559999999999996

# %%
binom.pmf(n=4, p=3/5, k=3)
# Out:
# np.float64(0.3456)

# %%
math.comb(4, 4) * (3/5)**4 * (2/5)**0
# Out:
# 0.1296

# %%
binom.pmf(n=4, p=3/5, k=4)
# Out:
# np.float64(0.1296)

# %%
n = 4
p = 3/5
expectation = 0
for k in range(n+1):
    expectation += k * binom.pmf(n=n, k=k, p=p)


expectation
# Out:
# np.float64(2.4000000000000004)

# %% [markdown]
# # Game

# %%
len(red_values)
# Win 150 if 4R, lose 10 otherwise

money = 0
for val in red_values:
    if val == 4:
        money += 150
    else:
        money -= 10
        
money/len(red_values)
# Out:
# 10.912
